# %%
#drop all the null values
#replace '-' value with column mean 
#encode lender asset into 0,1,2
#replace '.' with column mean

# %%
import pandas as pd
import numpy as np

# %%
ld = pd.read_excel('Lending Data.xlsx')

# %%
ld.head()
# Out:
#   Name of Lending Institution HQ State Rank TA Ratio1 TBL Ratio1  \
# 0                         NaN      NaN   -1        -2         -3
# 1       American Express Co.       NY     1   0.23829   0.999544
# 2    First Citizens Banchares      NC     2  0.187393    0.49083
# 3    Wintrust Financial Corp.      IL     3  0.168999   0.383561
# 4               Zions Bancorp      UT     4  0.117973   0.260577
#
#   Amount ($1,000)  Number      Lender Asset Size  Amount ($1,000).1  \
# 0              -4       -5                    -6               -7.0
# 1        16350038  3603226  >$50B                        16318089.0
# 2         3914507   117702  $10B-$50B                      378394.0
# 3         2842793   136801  $10B-$50B                      800526.0
# 4         6231770    52612  >$50B                          526206.0
#
#    Number .1  Unnamed: 10  Amount ($1,000).2  Number .2 CC Amount/TA1
# 0       -8.0          NaN               -9.0      -10.0           -11
# ...

# %%
ld.describe()
# Out:
#        Amount ($1,000).1     Number .1  Unnamed: 10  Amount ($1,000).2  \
# count       9.400000e+01  9.400000e+01          0.0       9.400000e+01
# mean        9.919647e+05  1.964819e+05          NaN       2.023422e+06
# std         2.818599e+06  6.639889e+05          NaN       3.679601e+06
# min        -7.000000e+00 -8.000000e+00          NaN      -9.000000e+00
# 25%         1.940850e+04  6.905000e+02          NaN       1.795375e+05
# 50%         1.278210e+05  7.593000e+03          NaN       8.526710e+05
# 75%         5.284680e+05  3.304275e+04          NaN       2.272185e+06
# max         1.631809e+07  3.603088e+06          NaN       2.615439e+07
#
#            Number .2
# count      94.000000
# mean     8425.255319
# std     15008.480842
# min       -10.000000
# 25%       550.000000
# 50%      3344.000000
# 75%     10750.000000
# max    107411.000000

# %%
#drop all the null values

# %%
ld=ld.drop(columns=['Unnamed: 10']).dropna()

# %%
ld
# Out:
#           Name of Lending Institution HQ State Rank TA Ratio1 TBL Ratio1  \
# 1               American Express Co.       NY     1   0.23829   0.999544
# 2            First Citizens Banchares      NC     2  0.187393    0.49083
# 3            Wintrust Financial Corp.      IL     3  0.168999   0.383561
# 4                       Zions Bancorp      UT     4  0.117973   0.260577
# 5             Synovus Financial Corp.      GA     5  0.162333   0.381387
# ..                                ...      ...  ...       ...        ...
# 89  USAA Svg. Bank                          NV   NR         0          -
# 90                State Street Corp.       MA    NR         -          -
# 91     E Trade Bk                           VA   NR         -          -
# 92     Charles Schwab Bk                    NV   NR         -          -
# 93     Third FS&LA                          OH   NR         -          -
#
#    Amount ($1,000)  Number      Lender Asset Size  Amount ($1,000).1  \
# ...

# %%
#replace '-'and '.' value with column mean

# %%
ld2=ld.copy()

# %%
ld2[ld2=='-']=np.nan
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py:1115: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)

# %%
ld2
# Out:
#           Name of Lending Institution HQ State Rank TA Ratio1 TBL Ratio1  \
# 1               American Express Co.       NY     1   0.23829   0.999544
# 2            First Citizens Banchares      NC     2  0.187393    0.49083
# 3            Wintrust Financial Corp.      IL     3  0.168999   0.383561
# 4                       Zions Bancorp      UT     4  0.117973   0.260577
# 5             Synovus Financial Corp.      GA     5  0.162333   0.381387
# ..                                ...      ...  ...       ...        ...
# 89  USAA Svg. Bank                          NV   NR         0        NaN
# 90                State Street Corp.       MA    NR       NaN        NaN
# 91     E Trade Bk                           VA   NR       NaN        NaN
# 92     Charles Schwab Bk                    NV   NR       NaN        NaN
# 93     Third FS&LA                          OH   NR       NaN        NaN
#
#    Amount ($1,000)  Number      Lender Asset Size  Amount ($1,000).1  \
# ...

# %%
ld2[ld2=='    .  ']=np.nan

# %%
ld2
# Out:
#           Name of Lending Institution HQ State Rank TA Ratio1 TBL Ratio1  \
# 1               American Express Co.       NY     1   0.23829   0.999544
# 2            First Citizens Banchares      NC     2  0.187393    0.49083
# 3            Wintrust Financial Corp.      IL     3  0.168999   0.383561
# 4                       Zions Bancorp      UT     4  0.117973   0.260577
# 5             Synovus Financial Corp.      GA     5  0.162333   0.381387
# ..                                ...      ...  ...       ...        ...
# 89  USAA Svg. Bank                          NV   NR         0        NaN
# 90                State Street Corp.       MA    NR       NaN        NaN
# 91     E Trade Bk                           VA   NR       NaN        NaN
# 92     Charles Schwab Bk                    NV   NR       NaN        NaN
# 93     Third FS&LA                          OH   NR       NaN        NaN
#
#    Amount ($1,000)  Number      Lender Asset Size  Amount ($1,000).1  \
# ...

# %%
ld2=ld2.fillna(value=ld2.mean())
ld2
# Out:
#           Name of Lending Institution HQ State Rank  TA Ratio1  TBL Ratio1  \
# 1               American Express Co.       NY     1   0.238290    0.999544
# 2            First Citizens Banchares      NC     2   0.187393    0.490830
# 3            Wintrust Financial Corp.      IL     3   0.168999    0.383561
# 4                       Zions Bancorp      UT     4   0.117973    0.260577
# 5             Synovus Financial Corp.      GA     5   0.162333    0.381387
# ..                                ...      ...  ...        ...         ...
# 89  USAA Svg. Bank                          NV   NR   0.000000    0.251196
# 90                State Street Corp.       MA    NR   0.048668    0.251196
# 91     E Trade Bk                           VA   NR   0.048668    0.251196
# 92     Charles Schwab Bk                    NV   NR   0.048668    0.251196
# 93     Third FS&LA                          OH   NR   0.048668    0.251196
#
# ...

# %%
# encode lender asset into 0,1,2

# %%
ld3=ld2.copy()

# %%
ld3
# Out:
#           Name of Lending Institution HQ State Rank  TA Ratio1  TBL Ratio1  \
# 1               American Express Co.       NY     1   0.238290    0.999544
# 2            First Citizens Banchares      NC     2   0.187393    0.490830
# 3            Wintrust Financial Corp.      IL     3   0.168999    0.383561
# 4                       Zions Bancorp      UT     4   0.117973    0.260577
# 5             Synovus Financial Corp.      GA     5   0.162333    0.381387
# ..                                ...      ...  ...        ...         ...
# 89  USAA Svg. Bank                          NV   NR   0.000000    0.251196
# 90                State Street Corp.       MA    NR   0.048668    0.251196
# 91     E Trade Bk                           VA   NR   0.048668    0.251196
# 92     Charles Schwab Bk                    NV   NR   0.048668    0.251196
# 93     Third FS&LA                          OH   NR   0.048668    0.251196
#
# ...

# %%
ld3['Lender Asset Size']=ld3['Lender Asset Size'].astype('category').cat.rename_categories([0, 1, 2])

# %%
ld3
# Out:
#           Name of Lending Institution HQ State Rank  TA Ratio1  TBL Ratio1  \
# 1               American Express Co.       NY     1   0.238290    0.999544
# 2            First Citizens Banchares      NC     2   0.187393    0.490830
# 3            Wintrust Financial Corp.      IL     3   0.168999    0.383561
# 4                       Zions Bancorp      UT     4   0.117973    0.260577
# 5             Synovus Financial Corp.      GA     5   0.162333    0.381387
# ..                                ...      ...  ...        ...         ...
# 89  USAA Svg. Bank                          NV   NR   0.000000    0.251196
# 90                State Street Corp.       MA    NR   0.048668    0.251196
# 91     E Trade Bk                           VA   NR   0.048668    0.251196
# 92     Charles Schwab Bk                    NV   NR   0.048668    0.251196
# 93     Third FS&LA                          OH   NR   0.048668    0.251196
#
# ...
